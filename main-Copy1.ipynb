# %%
import pandas as pd
from glob2 import glob
import os
from IPython.display import display, HTML
from tqdm import tqdm
import shutil

def show_df(df):
    if isinstance(df, pd.Series):
        display(HTML(df.to_frame().to_html()))
    else:
        display(HTML(df.to_html()))
    print("table shape:", df.shape)


def extract_head(df):
    heads = df.iloc[3].tolist()
    name = df.columns[0]
    for i,  h in enumerate(heads):
        if str(h)== 'nan':
            heads[i] = df.iloc[4,i]
    heads[0] = name + " "+ heads[0] + " " + df.iloc[2,0]
    return heads


def extract_row(df, kw):
    res = []
    for i, cls in enumerate(df.iloc[:,0].tolist()):
        if str(cls).find(kw)!=-1:
            res.append( df.iloc[i] )
    if len(res)==0:
        return None
    return pd.concat(res, axis=0)


#     heads = extract_head(df)
#     df.columns = heads
#     r = extract_row(df, "橡胶").to_frame().T


# shengfen = [os.path.split(t)[-1] for t in glob(r'E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\*')]

# shengfen = ['安徽']    txt chm格式有问题
# shengfen = ['澳门']    pdf格式有问题
# shengfen = ['北京']
# shengfen = ['福建']
# shengfen = ['甘肃']
# shengfen = ['广东']
# shengfen = ['广西']
# shengfen = ['贵州']
# shengfen = ['海南']
# shengfen = ['河北']
# shengfen = ['河南']
# shengfen = ['黑龙江']
# shengfen = ['湖北']
# shengfen = ['湖南']
# shengfen = ['吉林']
# shengfen = ['江苏']
# shengfen = ['江西']
# shengfen = ['辽宁']
# shengfen = ['内蒙古']
# shengfen = ['宁夏']
# shengfen = ['青海']
# shengfen = ['山东']
# shengfen = ['山西']
# shengfen = ['陕西']
# shengfen = ['上海']
# shengfen = ['四川']
# shengfen = ['台湾']
# shengfen = ['天津']
# shengfen = ['西藏']
shengfen = ['香港']
# shengfen = ['新疆'] 
# shengfen = ['云南']
# shengfen = ['浙江']
# shengfen = ['重庆']

# shengfen = list(set(shengfen)-set(['山东']))
root_path = r"E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴"
save_path = "F:\\nianjianjieguo"

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Administrator\Desktop\a.txt')
df.to_excel(r'C:\Users\Administrator\Desktop\a.xlsx')

# %%
# # -*- coding: utf-8 -*-    python transfer txt to excel
# """
# QQ2737499951
# """
 
# import openpyxl
# import codecs
# from openpyxl.utils import get_column_letter
 
# def txt_to_xlsx(filename,outfile):
 
#     fr = codecs.open(filename,'r')
#     wb = openpyxl.Workbook()
#     ws = wb.active
#     ws = wb.create_sheet()
#     ws.title = 'Sheet1'
#     row = 0
#     for line in fr:
#         row +=1
#         line = line.strip()
#         line = line.split('\t')
#         col = 0
#         for j in range(len(line)):
#             col +=1
#             #print (line[j])
#             ws.cell(column = col,row = row,value = line[j].format(get_column_letter(col)))
#     wb.save(outfile)
# #读取xlsx内容    
# def read_xlsx(filename):
#     #载入文件
#     wb = openpyxl.load_workbook(filename)
#     #获取Sheet1工作表
#     ws = wb.get_sheet_by_name('Sheet1')
#     #按行读取
#     for row in ws.rows:
#         for cell in row:
#             print (cell.value)
#     #按列读
#     for col in ws.columns:
#         for cell in col:
#             print (cell.value)
 
# if __name__=='__main__':
# #     inputfileTxt = 'test.txt'
#     inputfileTxt = r'C:\Users\Administrator\Desktop\a.txt'
#     outfileExcel = 'text_result.xlsx'
# #     txt_to_xlsx(inputfileTxt,outfileExcel)
#     read_xlsx(outfileExcel)
# Out:
# 123
# 345
# 234
# 123
# 345
# 234
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).

# %%
# copy xls
for sf in shengfen:
    paths = [t for t in glob(os.path.join(root_path, sf, '*')) if os.path.isdir(t)]
    for path in paths:
        files = glob(os.path.join(path, '**', '*.xls*'))
        print("{}, {}".format(os.path.split(path)[-1], len(files)))
        xls_path = os.path.join(path, 'xls')
        if not os.path.exists(xls_path): os.mkdir(xls_path)
        for f in files:
            try:
                shutil.copy(f, xls_path)
            except:
                pass
        if len(files)==0:                                         # single html to excel
            files_html = glob(os.path.join(path, '**', '*.htm*'))
            for f in files_html: 
                try:
                    htm = pd.read_html(f)
                    ff = os.path.join(os.path.split(f)[0], os.path.split(f)[-1].split('.')[0]+".xlsx" )
                    htm[0].to_excel(ff)
                    print(ff)
                except:
                    pass                  
            files_excel = glob(os.path.join(path, '**', '*.xls*'))        #single copy xls
            print("{}, {}".format(os.path.split(path)[-1], len(files_excel)))
            xls_path = os.path.join(path, 'xls')
            if not os.path.exists(xls_path): os.mkdir(xls_path)
            for f in files:
                try:
                    shutil.copy(f, xls_path)
                except:
                    pass
# Out:
# 香港统计年刊2018, 8
# 香港统计年刊（PDF、EXCEL版）, 4

# %%
# html to excel

# for sf in shengfen:
#     paths = [t for t in glob(os.path.join(root_path, sf, '*')) if os.path.isdir(t)]
#     for path in paths:
#         files = glob(os.path.join(path, '**', '*.htm*'))
#         for f in files: 
#             try:
#                 htm = pd.read_html(f)
#                 ff = os.path.join(os.path.split(f)[0], os.path.split(f)[-1].split('.')[0]+".xlsx" )
#                 htm[0].to_excel(ff)
#                 print(ff)
#             except:
#                 pass
# Out:
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\left.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\lefte.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\left_.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\left_e.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0101a.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0101b.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0102.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0103.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0104.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0105.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0106.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0107.xlsx
# E:\孙宗帝资料\2020年博士毕业相关资料\论文年鉴资料\省份年鉴\湖南\2011年湖南统计年鉴\湖南统计年鉴2011\html\0108.xlsx
# ...

# %%
# copy xls
# for sf in shengfen:
#     paths = [t for t in glob(os.path.join(root_path, sf, '*')) if os.path.isdir(t)]
#     for path in paths:
#         files = glob(os.path.join(path, '**', '*.xls*'))
#         print("{}, {}".format(os.path.split(path)[-1], len(files)))
#         xls_path = os.path.join(path, 'xls')
#         if not os.path.exists(xls_path): os.mkdir(xls_path)
#         for f in files:
#             try:
#                 shutil.copy(f, xls_path)
#             except:
#                 pass
# Out:
# 2010湖南统计年鉴, 36
# 2011年湖南统计年鉴, 1675
# 2012年湖南统计年鉴, 1728
# 2013年湖南统计年鉴, 44
# 2014年湖南统计年鉴, 868
# 湖南统计年鉴2000, 770
# 湖南统计年鉴2001（光盘版）, 822
# 湖南统计年鉴2002（光盘版）, 1612
# 湖南统计年鉴2003（光盘版）, 0
# 湖南统计年鉴2004（光盘版）, 1542
# 湖南统计年鉴2005（光盘版）, 871
# 湖南统计年鉴2006（光盘版）, 1033
# 湖南统计年鉴2007（光盘版）, 1033
# 湖南统计年鉴2008（光盘版）, 523
# 湖南统计年鉴2009（光盘版）, 896
# 湖南统计年鉴2015(光盘版), 867
# 湖南统计年鉴2016（光盘版）, 868
# 湖南统计年鉴2017（光盘版）, 832
# 湖南统计年鉴2018（光盘版）, 938

# %%
cnt = 0

for sf in tqdm(shengfen):
    path_sf = os.path.join(root_path, sf)
#     files = glob(os.path.join(path_sf, '**', '*.xls*'))
    files = glob(os.path.join(path_sf, '*','xls', '*.xls*'))
    years_list = list(set([ t.split('\\')[-3] for t in files ]))
    
    for year in tqdm(years_list):
        files = glob(os.path.join(path_sf, year, '**', "*.xls*"))
    
        res = {}
        bad = []

        for f in files:
            try:
                xl = pd.ExcelFile(f)
                sheet_names = xl.sheet_names
            except:
#                 print("bad read:", f)
                bad.append(f)
                continue
            name = os.path.split(f)[-1].split('.')[0]

            for sheet in sheet_names:
                df = xl.parse(sheet)
                if (df.shape[0]<10): continue
                ind = df.iloc[:,0].map(lambda t: str(t).find('橡胶')!=-1 or str(t).find('塑料')!=-1 or str(t).find('轮胎')!=-1 )
                if (ind.sum()==0): continue
#                 print("find {} {} {}".format(sf, year, name))
                sel = df.loc[ind]
                header = df.iloc[:10,:]
                mer = pd.concat( [header, sel], axis=0 )
                res[name] = mer
        
        if not os.path.exists(os.path.join(save_path, sf)):
            os.mkdir(os.path.join(save_path, sf))
        
        writer = pd.ExcelWriter(os.path.join(save_path, sf, "{}.xlsx".format(year)))
        sheet_names = []
        for k,v in res.items():
            name = str(v.columns[0]).lower()
            for c in r"\[]:*?/":
                name = name.replace(c, '')
            if len(name)>31: name = name[:31]
            if name=='nan' or len(name)==0 or name in sheet_names:
                name = k.lower()
                for c in r"\[]:*?/":
                    name = name.replace(c, '')
                if len(name)>31: name = name[:28]
                if name in sheet_names: 
                    name = name + "_" + str(cnt)
                    cnt += 1
            sheet_names.append(name)
            v.to_excel(writer, sheet_name=name)

        writer.save()
        with open( os.path.join(save_path, sf, "{}_bad_read.txt".format(year)), "w") as fd:
            for t in bad:
                fd.write(t+"\n")
# Out:
# ...
# 100%|███████████████████████████████████████████| 1/1 [01:41<00:00, 101.31s/it]
